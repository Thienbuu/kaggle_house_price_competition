# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option("display.max_columns", 999)
pd.set_option("display.max_rows", 999)

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

print("Train data shape: ", train.shape)
print("Test data shape: ", test.shape)
# Out:
# Train data shape:  (1460, 81)
# Test data shape:  (1459, 80)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# We have column **YrSold** which is the year the house was sold, it should be have relationship with **SalePrice** column. So we shill explore it

# %% [markdown]
# ## Data visualization

# %%
plt.style.use(style="ggplot")
plt.rcParams["figure.figsize"] = (10,6)

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# The average price of sale price is  \\$160.000 which is close to the mean \\$180.000 with mot values fall between \\$130.000 and \\$214.000.
#
# Next We will explore the distribution of sale price

# %%
print("SalePrice skew is: ", train["SalePrice"].skew())
plt.hist(train['SalePrice'], bins=15)
plt.show()
# Out:
# SalePrice skew is:  1.8828757597682129

# %% [markdown]
# Now we use np.log() to transform **SalePrice** and calculate the skewness for the second time, as well as re-plot the data.

# %%
target = np.log(train["SalePrice"])
print("Skew is: ", target.skew())
plt.hist(target, bins=15)
plt.show()
# Out:
# Skew is:  0.12133506220520406

# %% [markdown]
# The skew value is getting closer to 0 that means we have improved the skewness of the data

# %% [markdown]
# Now we've already transformed target variable. Let's nove on our features

# %% [markdown]
# First we check out the numerical features and make some plots.

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
corr = numeric_features.corr()
print(corr["SalePrice"].sort_values(ascending=False)[:5], "\n")
print(corr["SalePrice"].sort_values(ascending=False)[-5:])
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# **OverallQual** column has the most positive relationship with **SalePrice**, so we will dig depper on this feature

# %%
train["OverallQual"].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %% [markdown]
# We will create a pivot table to investigate the relationship between **OverallQual** and **SalePrice**

# %%
quality_pivot = train.pivot_table(index="OverallQual", values="SalePrice", aggfunc=np.median)
quality_pivot
# Out:
#              SalePrice
# OverallQual
# 1                50150
# 2                60000
# 3                86250
# 4               108000
# 5               133000
# 6               160000
# 7               200141
# 8               269750
# 9               345000
# 10              432390

# %%
quality_pivot.plot(kind="bar", legend=None)
plt.xlabel("Overall Quality")
plt.ylabel("Sale Price")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Notice that the median sales price increases as overall quality increases

# %% [markdown]
# Next, we will explore the relationship between **GrLivArea** and **SalePrice**
#
# We will use scatter plot to visualize the relationship between theses columns

# %%
plt.scatter(x=train["GrLivArea"], y=target)
plt.xlabel("Above grade (ground) living area square feet")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# At first glance, we can see that the living area increases will make the sale price increases.
#
# We will do the same for **GarageArea** column

# %%
plt.scatter(x=train["GarageArea"], y=target)
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# We see that there are some house with 0 in **Garage Area**, indicating that they don't have a garage. Also we can notice that there are some outliers, these outliers may affect to out model further. So, we'll remove those observations from out data.

# %% [markdown]
# We try to create a new dataframe with outliers removed

# %%
train = train[train["GarageArea"] < 1000]

# %% [markdown]
# Let's review our plot after removing outliers

# %%
plt.scatter(x=train["GarageArea"], y=np.log(train["SalePrice"]))
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# Notice that we get a better intuition after removing some outliers from **Garage Area**

# %% [markdown]
# ## Handling missing values

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False))[:25]
nulls.columns = ["Null Count"]
nulls.index.name = "Feature"
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1439
# MiscFeature         1392
# Alley               1354
# Fence               1165
# FireplaceQu          689
# LotFrontage          256
# GarageCond            81
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# Utilities              0
# YearRemodAdd           0
# MSSubClass             0
# Foundation             0
# ExterCond              0
# ExterQual              0

# %% [markdown]
# As the description provides, **PoolQC** refers to Pool Quality. Pool Quality is **NaN** when **PoolArea** is 0 or there is no pool.

# %% [markdown]
# Let's investigate **MicsFeature** column.

# %%
print("Unique values are: ", train["MiscFeature"].unique())
# Out:
# Unique values are:  [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %% [markdown]
# With the information we get from documentation, this column indicates that house has over 100 square feet or not ? Does it have a second garage, tennis court ? and so on. It is an important information to gather domain knowledge to make the best decisions when dealing with  missing data.

# %% [markdown]
# ## Wragling the non-numeric Features

# %%
cateroricals = train.select_dtypes(exclude=[np.number])
cateroricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1445   1445    91     1445        1445      1445      1445
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1140   1440    50      915        1299      1444      1041
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1445         1445       1445       1445     1445       1445
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1369          225       1248       1431     1207        719
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1445     1445        1445        1445       1437      1445
# unique         6        7          15          16          4         4
# top        Gable  CompShg     VinylSd     VinylSd       None        TA
# freq        1133     1420         506         495        859       904
#
#        ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# count       1445       1445     1408     1408         1407         1408
# unique         5          6        4        4            4            6
# top           TA      PConc       TA       TA           No          Unf
# freq        1269        635      646     1296          949          424
#
#        BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# count          1407    1445      1445       1445       1444        1445
# unique            6       6         5          2          5           4
# top             Unf    GasA        Ex          Y      SBrkr          TA
# freq           1241    1413       728       1350       1319         733
#
#        Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# count        1445         756       1364         1364       1364       1364
# unique          7           5          6            3          5          5
# top           Typ          Gd     Attchd          Unf         TA         TA
# freq         1345         370        860          604       1296       1311
#
#        PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# count        1445      6    280          53     1445          1445
# unique          3      3      4           4        9             6
# top             Y     Fa  MnPrv        Shed       WD        Normal
# freq         1325      2    157          48     1262          1192

# %% [markdown]
# ## Transforming and engineering features

# %% [markdown]
# ### Street

# %%
print("Original: \n")
print(train["Street"].value_counts())
# Out:
# Original:
#
# Pave    1440
# Grvl       5
# Name: Street, dtype: int64

# %%
train["enc_street"] = pd.get_dummies(data=train["Street"], drop_first=True)
test["enc_street"] = pd.get_dummies(data=train["Street"], drop_first=True)

# %%
print("Encoded: \n")
print(train["enc_street"].value_counts())
# Out:
# Encoded:
#
# 1    1440
# 0       5
# Name: enc_street, dtype: int64

# %% [markdown]
# ### Sale Condition

# %%
condition_pivot = train.pivot_table(index="SaleCondition", values="SalePrice", aggfunc=np.median)
condition_pivot.plot(kind="bar", legend=None)
plt.xlabel("Sale Condition")
plt.ylabel("Median Sale Price")
plt.show()

# %% [markdown]
# Notice that the partial has a significantly higher Median Sale Price than the others. We will encode this as a new feature. We select all the houses where **SaleCondition** is equal to **Partial** and assign the value 1, otherwise assign 0

# %%
def encode(x):
    return 1 if x == 'Partial' else 0
train["enc_condition"] = train["SaleCondition"].apply(encode)
test["end_condition"] = test["SaleCondition"].apply(encode)

# %% [markdown]
# Let's plot this new feature

# %%
condition_pivot = train.pivot_table(index="enc_condition", values="SalePrice", aggfunc=np.median)
condition_pivot.plot(kind="bar", legend=None)
plt.xlabel("Encoded Sale Condition")
plt.ylabel("Median Sale Price")
plt.show()

# %% [markdown]
# To build our first model, we need to deal with missing data. One way to to quickly remove missing data is using average value and assign it to data. This is call **interpolate**.
#
# Although it is a simple and quick method but it may not lead us to a good performance for our model when new data come up, but we will try this method to quickly build a model and predict.

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna()

# %%
sum(data.isnull().sum() != 0)
# Out:
# 0

# %% [markdown]
# All missing data have been  filled

# %% [markdown]
# ## Build a linear model

# %%
y = np.log(train["SalePrice"])
X = data.drop(["SalePrice", "Id"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# %%
lr = LinearRegression()
model = lr.fit(X_train, y_train)

# %%
print("R^2 is: ", model.score(X_test, y_test))
# Out:
# R^2 is:  0.8855402905982253

# %% [markdown]
# We get R-squared score approximately 89%, which is good since R-squared value is between 0 and 1, 1 meaning that all of the variance in the target is explained by the data. In general, a higher R-squared means a better fit.

# %% [markdown]
# Let's predict our model

# %%
predictions = model.predict(X_test)

# %%
print("RMSE is: \n", mean_squared_error(y_test, predictions))
# Out:
# RMSE is:
#  0.016444486374717678

# %% [markdown]
# Interpret this value is somewhat more intuitive that the R-squared value. The RMSE measures the distance betwene our predicted values and actual values.
#
# We can view this relationship graphically with a scatter plot

# %%
actual_values = y_test
fig = plt.figure(figsize=(10,7))
plt.scatter(predictions, actual_values, alpha=.7)
plt.xlabel("Predicted Price")
plt.ylabel("Acutal Price")
plt.title("Linear Regression Model")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# If our predicted values were identical to the actual values, this graph would be the straight line y=x because each predicted value x would be equal to each actual value y.

# %% [markdown]
# ### Try to improve the model

# %% [markdown]
# We'll next try using  **Ridge Regularization** to decrease the influence of less important features. Ridge Regularization is a process which shrinks the regression coefficients of less important features.
#
# We'll once again instantiate the model. The Ridge Regularization model takes a parameter, **alpha**, which control the strength of the regularization.
#
# We'll experiment by looping through a few different values of alpha, and see how this changes our results.

# %%
for i in range(-2,3):
    alpha = 10**i
    rm = Ridge(alpha=alpha)
    ridge_model = rm.fit(X_train, y_train)
    preds_ridge = ridge_model.predict(X_test)
    
    fig = plt.figure(figsize=(10,8))
    plt.scatter(preds_ridge, actual_values, alpha=0.75)
    plt.xlabel("Predicted Price")
    plt.ylabel("Actual Price")
    plt.title("Ridge Regularizaiton with alpha {}".format(alpha))
    overlay = "R^2 is: {}.\n RMSE is: {}".format(
                    ridge_model.score(X_test, y_test),
                    mean_squared_error(preds_ridge, y_test))
    plt.annotate(s=overlay, xy=(12.1, 10.6), size='x-large')
    plt.show()

# %% [markdown]
# These models perform almost identically to the first model. In our case, adjusting the alpha did not substantially improve our model. As you add more features, regularization can be helpful. We will repeat this step after added more features.

# %% [markdown]
# ## Make a submission

# %%
submission = pd.DataFrame()
submission['Id'] = test['Id']

# %%
feats = test.select_dtypes(include=[np.number]).drop(['Id'], axis=1).interpolate()

# %%
predictions = model.predict(feats)

# %% [markdown]
# Now we'll transform the predictions to the correct form. Remember that to reserve **log()** we do **exp()**.
#
# So we apply **np.exp()** to our predictions because we have taken the logarithm previously.

# %%
final_predictions = np.exp(predictions)

# %%
print("Original predictions are: \n", predictions[:5], "\n")
print("Final predicctions are: \n", final_predictions[:5], "\n")
# Out:
# Original predictions are:
#  [11.72812448 11.94222372 12.06259708 12.19216276 12.09873188]
#
# Final predicctions are:
#  [124010.86778809 153617.9133594  173268.39389924 197237.28217717
#  179643.9082368 ]

# %% [markdown]
# Let's assign these predictions and check that everything looks good

# %%
submission["SalePrice"] = final_predictions
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  124010.867788
# 1  1462  153617.913359
# 2  1463  173268.393899
# 3  1464  197237.282177
# 4  1465  179643.908237

# %%
submission.to_csv("submission1.csv", index=False)
