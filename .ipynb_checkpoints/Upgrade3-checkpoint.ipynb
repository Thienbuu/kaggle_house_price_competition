# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline
pd.set_option("display.max_columns", 999)
pd.set_option("display.max_rows", 999)

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.feature_selection import RFECV

# %%
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

print("Train data shape: ", train.shape)
print("Test data shape: ", test.shape)
# Out:
# Train data shape:  (1460, 81)
# Test data shape:  (1459, 80)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# We have column **YrSold** which is the year the house was sold, it should be have relationship with **SalePrice** column. So we shill explore it

# %% [markdown]
# # Data visualization

# %%
plt.style.use(style="ggplot")
plt.rcParams["figure.figsize"] = (10,6)

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# The average price of sale price is  \\$160.000 which is close to the mean \\$180.000 with mot values fall between \\$130.000 and \\$214.000.
#
# Next We will explore the distribution of sale price

# %% [markdown]
# Now we use np.log() to transform **SalePrice** and calculate the skewness for the second time, as well as re-plot the data.

# %%
print("SalePrice skew is: ", train["SalePrice"].skew())
plt.hist(train['SalePrice'], bins=15)
plt.show()
# Out:
# SalePrice skew is:  1.8828757597682129

# %%
target = np.log(train["SalePrice"])
print("Skew is: ", target.skew())
plt.hist(target, bins=15)
plt.show()
# Out:
# Skew is:  0.12133506220520406

# %% [markdown]
# The skew value is getting closer to 0 that means we have improved the skewness of the data

# %% [markdown]
# Now we've already transformed target variable. Let's nove on our features

# %% [markdown]
# First we check out the numerical features and make some plots.

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
corr = numeric_features.corr()
print(corr["SalePrice"].sort_values(ascending=False)[:10], "\n")
print(corr["SalePrice"].sort_values(ascending=False)[-5:])
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# **OverallQual** column has the most positive relationship with **SalePrice**, so we will dig depper on this feature

# %%
train["OverallQual"].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %% [markdown]
# We will create a pivot table to investigate the relationship between **OverallQual** and **SalePrice**

# %%
quality_pivot = train.pivot_table(index="OverallQual", values="SalePrice", aggfunc=np.median)
quality_pivot
# Out:
#              SalePrice
# OverallQual
# 1                50150
# 2                60000
# 3                86250
# 4               108000
# 5               133000
# 6               160000
# 7               200141
# 8               269750
# 9               345000
# 10              432390

# %%
quality_pivot.plot(kind="bar", legend=None)
plt.xlabel("Overall Quality")
plt.ylabel("Sale Price")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Notice that the median sales price increases as overall quality increases

# %% [markdown]
# Next, we will explore the relationship between **GrLivArea** and **SalePrice**
#
# We will use scatter plot to visualize the relationship between theses columns

# %%
plt.scatter(x=train["GrLivArea"], y=target)
plt.xlabel("Above grade (ground) living area square feet")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# At first glance, we can see that the living area increases will make the sale price increases.

# %% [markdown]
# We will do the same for **GarageArea** column

# %%
plt.scatter(x=train["GarageArea"], y=target)
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# We see that there are some house with 0 in **Garage Area**, indicating that they don't have a garage. Also we can notice that there are some outliers, these outliers may affect to out model further. So, we'll remove those observations from out data.

# %% [markdown]
# We try to create a new dataframe with outliers removed

# %%
train = train[train["GarageArea"] < 1000]

# %% [markdown]
# Let's review our plot after removing outliers

# %%
plt.scatter(x=train["GarageArea"], y=np.log(train["SalePrice"]))
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# Notice that we get a better intuition after removing some outliers from **Garage Area**

# %% [markdown]
# # Handling missing values

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False))[:25]
nulls.columns = ["Null Count"]
nulls.index.name = "Feature"
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1439
# MiscFeature         1392
# Alley               1354
# Fence               1165
# FireplaceQu          689
# LotFrontage          256
# GarageCond            81
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# Utilities              0
# YearRemodAdd           0
# MSSubClass             0
# Foundation             0
# ExterCond              0
# ExterQual              0

# %% [markdown]
# If we read the description for each feature in **data_description.txt** file we can notice that there are 2 main missing value column types:
# - ***Group 1***: Missing values refer to there is no addition feature <br>
#   We can will this type of missing value with addition string, in this case, **Zero** can be a choice
# - ***Group 2***: Missing values which there is no description about that missing <br>
#   We need to find out the relationship of those columns with other columns to fill missing values

# %%
fill_with_zero_cols = ["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu", 
                      "GarageCond", "GarageType", "GarageFinish", "GarageQual", 
                      "BsmtExposure", "BsmtFinType2", "BsmtFinType1", "BsmtCond", "BsmtQual",
                      "MasVnrType"]
missing_cols = ["LotFrontage", "GarageYrBlt", "MasVnrArea", "Electrical"]

# %% [markdown]
# ## Fill missing values with Zero

# %%
train[fill_with_zero_cols] = train[fill_with_zero_cols].fillna("Zero")
test[fill_with_zero_cols] = test[fill_with_zero_cols].fillna("Zero")

# %% [markdown]
# Check again to be sure there are only 4 columns remain

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False))[:6]
nulls.columns = ["Null Counts"]
nulls.index.name = "Features"
nulls
# Out:
#              Null Counts
# Features
# LotFrontage          256
# GarageYrBlt           81
# MasVnrArea             8
# Electrical             1
# SalePrice              0
# ExterCond              0

# %% [markdown]
# ## Fill other columns

# %% [markdown]
# ### Electrical

# %%
print("Unique values are: ", train["Electrical"].unique())
print("\nMissing values are: ", train["Electrical"].isnull().sum())
# Out:
# Unique values are:  ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
#
# Missing values are:  1

# %% [markdown]
# We will fill this missing value by column mode

# %%
print("Mode is: ", train["Electrical"].mode()[0])
# Out:
# Mode is:  SBrkr

# %%
train["Electrical"].fillna(train["Electrical"].mode()[0], inplace=True)
test["Electrical"].fillna(test["Electrical"].mode()[0], inplace=True)

# %% [markdown]
# ### MasVnrArea

# %% [markdown]
# If we check the data and description carefully, we can notice that if the value in **MasVnrType** is **NaN** or **None** as written in description, then the value in this column will also be **NaN**.
# <br>
# Therefore we will fill all missing values in this columns with 0.

# %%
train["MasVnrArea"].fillna(0, inplace=True)
test["MasVnrArea"].fillna(0, inplace=True)

# %% [markdown]
# ### GarageYrBlt

# %% [markdown]
# We will treat this column like **MasVnrArea** since if the house doesn't have garage then we won't have the year the garage built.

# %%
train["GarageYrBlt"].fillna(0, inplace=True)
test["GarageYrBlt"].fillna(0, inplace=True)

# %% [markdown]
# ### LotFrontage

# %% [markdown]
# We can find out that almost missing values in **LotFrontage** will follow with missing values in **Alley**. But there are some cases that although **Alley** is Graved or Paved, **LotFrontage** still get missing values. There for we will fill this columns by filling missing values as 0 wherever **Alley** also empty and mean value if **Alley** is not empty

# %%
def fill_train_lotfrontage(row):
    alley = row["Alley"]
    lft = row["LotFrontage"]
    lft_mean = round(train["LotFrontage"].mean(),2)
    if pd.isnull(lft):
        if pd.isnull(alley):
            return 0
        else:
            return lft_mean
    return lft

def fill_test_lotfrontage(row):
    alley = row["Alley"]
    lft = row["LotFrontage"]
    lft_mean = round(test["LotFrontage"].mean(),2)
    if pd.isnull(lft):
        if pd.isnull(alley):
            return 0
        else:
            return lft_mean
    return lft

# %%
train["LotFrontage"] = train.apply(fill_train_lotfrontage, axis=1)
test["LotFrontage"] = test.apply(fill_test_lotfrontage, axis=1)

# %% [markdown]
# Check again to be sure there is no column that remains missing values

# %%
print("Train null values are: ", train.isnull().sum().sum())
print("Shape of train data: ", train.shape)
# Out:
# Train null values are:  0
# Shape of train data:  (1445, 81)

# %%
print("Test null values are: ", test.isnull().sum().sum())
print("Shape of test data: ", test.shape)
# Out:
# Test null values are:  22
# Shape of test data:  (1459, 80)

# %% [markdown]
# Because there are still some columns in test set have missing value, therefore we will fill them by the most common value of each column

# %% [markdown]
# ## Fill missing values of test set by mode

# %%
test_cols = test.columns
for col in test_cols:
    if test[col].isnull().sum() > 0:
        mode = test[col].mode()[0]
        test[col].fillna(mode, inplace=True)

# %%
print("Test null values are: ", test.isnull().sum().sum())
print("Shape of test data: ", test.shape)
# Out:
# Test null values are:  0
# Shape of test data:  (1459, 80)

# %% [markdown]
# Our data is ready to the next step

# %% [markdown]
# # Engineering features

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# We will find categorical-like in numeric columns

# %%
# numeric_cols = train.select_dtypes(include=[np.number])

# %%
unique_values_freq = {
    "Column": [],
    "Data Type": [],
    "Unique Values": [],
    "Mode": [],
    "Frequency": []
}
for col in train.columns:
    if col != 'Id' and col != 'SalePrice':
        unique_values_freq["Column"].append(col)
        unique_values_freq["Data Type"].append(train[col].dtype)
        unique_values_freq["Unique Values"].append(len(train[col].unique()))
        unique_values_freq["Mode"].append(train[col].mode()[0])
        unique_values_freq["Frequency"].append(train[col].value_counts(normalize=True).sort_values(ascending=False).iloc[0])
unique_values_freq_df = pd.DataFrame.from_dict(unique_values_freq)

# %%
unique_values_freq_df.sort_values(by=["Data Type","Unique Values"])
# Out:
#            Column Data Type  Unique Values     Mode  Frequency
# 47   BsmtHalfBath     int64              3        0   0.943253
# 49       HalfBath     int64              3        0   0.628374
# 46   BsmtFullBath     int64              4        0   0.587543
# 48       FullBath     int64              4        2   0.525952
# 51   KitchenAbvGr     int64              4        1   0.952941
# 55     Fireplaces     int64              4        0   0.476817
# 60     GarageCars     int64              5        2   0.569550
# 76         YrSold     int64              5     2009   0.230450
# 70       PoolArea     int64              7        0   0.995848
# 50   BedroomAbvGr     int64              8        3   0.551557
# 17    OverallCond     int64              9        5   0.559862
# 16    OverallQual     int64             10        5   0.274740
# 53   TotRmsAbvGrd     int64             12        6   0.277509
# 75         MoSold     int64             12        6   0.174394
# 0      MSSubClass     int64             15       20   0.368166
# 68      3SsnPorch     int64             20        0   0.983391
# 74        MiscVal     int64             20        0   0.964706
# 44   LowQualFinSF     int64             24        0   0.982007
# 19   YearRemodAdd     int64             61     1950   0.122491
# 69    ScreenPorch     int64             76        0   0.921107
# 18      YearBuilt     int64            112     2006   0.044291
# 67  EnclosedPorch     int64            120        0   0.856055
# 35     BsmtFinSF2     int64            144        0   0.884429
# 66    OpenPorchSF     int64            199        0   0.453287
# 65     WoodDeckSF     int64            272        0   0.523183
# 43       2ndFlrSF     int64            413        0   0.568858
# 61     GarageArea     int64            427        0   0.056055
# 33     BsmtFinSF1     int64            629        0   0.319031
# 37    TotalBsmtSF     int64            715        0   0.025606
# 42       1stFlrSF     int64            745      864   0.017301
# 36      BsmtUnfSF     int64            774        0   0.081661
# 45      GrLivArea     int64            851      864   0.015225
# 3         LotArea     int64           1062     7200   0.017301
# 58    GarageYrBlt   float64             98        0   0.056055
# 2     LotFrontage   float64            111    69.71   0.177163
# 25     MasVnrArea   float64            321        0   0.597924
# 4          Street    object              2     Pave   0.996540
# 8       Utilities    object              2   AllPub   0.999308
# 40     CentralAir    object              2        Y   0.934256
# 5           Alley    object              3     Zero   0.937024
# 10      LandSlope    object              3      Gtl   0.947405
# 64     PavedDrive    object              3        Y   0.916955
# 6        LotShape    object              4      Reg   0.633218
# 7     LandContour    object              4      Lvl   0.898962
# 26      ExterQual    object              4       TA   0.625606
# 52    KitchenQual    object              4       TA   0.507266
# 59   GarageFinish    object              4      Unf   0.417993
# 71         PoolQC    object              4     Zero   0.995848
# 1        MSZoning    object              5       RL   0.788927
# 9       LotConfig    object              5   Inside   0.720415
# 14       BldgType    object              5     1Fam   0.835294
# 24     MasVnrType    object              5     None   0.594464
# 27      ExterCond    object              5       TA   0.878201
# 29       BsmtQual    object              5       TA   0.447059
# 30       BsmtCond    object              5       TA   0.896886
# 31   BsmtExposure    object              5       No   0.656747
# 39      HeatingQC    object              5       Ex   0.503806
# 41     Electrical    object              5    SBrkr   0.913495
# 72          Fence    object              5     Zero   0.806228
# 73    MiscFeature    object              5     Zero   0.963322
# 20      RoofStyle    object              6    Gable   0.784083
# 28     Foundation    object              6    PConc   0.439446
# 38        Heating    object              6     GasA   0.977855
# 56    FireplaceQu    object              6     Zero   0.476817
# 62     GarageQual    object              6       TA   0.896886
# 63     GarageCond    object              6       TA   0.907266
# 78  SaleCondition    object              6   Normal   0.824913
# 21       RoofMatl    object              7  CompShg   0.982699
# 32   BsmtFinType1    object              7      Unf   0.293426
# 34   BsmtFinType2    object              7      Unf   0.858824
# 54     Functional    object              7      Typ   0.930796
# 57     GarageType    object              7   Attchd   0.595156
# 13     Condition2    object              8     Norm   0.990311
# 15     HouseStyle    object              8   1Story   0.497578
# 12     Condition1    object              9     Norm   0.863668
# 77       SaleType    object              9       WD   0.873356
# 22    Exterior1st    object             15  VinylSd   0.350173
# 23    Exterior2nd    object             16  VinylSd   0.342561
# 11   Neighborhood    object             25    NAmes   0.155709

# %%
numeric_unique_df = unique_values_freq_df[unique_values_freq_df["Data Type"] != 'object']
categorical_unqiue_df = unique_values_freq_df[unique_values_freq_df["Data Type"] == 'object']

# %% [markdown]
# Let's get columns which have 24 or less unique values and find the frequency of mode.
# If mode of column are greater than 60% entries, we will remove that column

# %%
numeric_unique_df.index = np.arange(len(numeric_unique_df))
numeric_unique_df
# Out:
#            Column Data Type  Unique Values   Mode  Frequency
# 0      MSSubClass     int64             15     20   0.368166
# 1     LotFrontage   float64            111  69.71   0.177163
# 2         LotArea     int64           1062   7200   0.017301
# 3     OverallQual     int64             10      5   0.274740
# 4     OverallCond     int64              9      5   0.559862
# 5       YearBuilt     int64            112   2006   0.044291
# 6    YearRemodAdd     int64             61   1950   0.122491
# 7      MasVnrArea   float64            321      0   0.597924
# 8      BsmtFinSF1     int64            629      0   0.319031
# 9      BsmtFinSF2     int64            144      0   0.884429
# 10      BsmtUnfSF     int64            774      0   0.081661
# 11    TotalBsmtSF     int64            715      0   0.025606
# 12       1stFlrSF     int64            745    864   0.017301
# 13       2ndFlrSF     int64            413      0   0.568858
# 14   LowQualFinSF     int64             24      0   0.982007
# 15      GrLivArea     int64            851    864   0.015225
# 16   BsmtFullBath     int64              4      0   0.587543
# 17   BsmtHalfBath     int64              3      0   0.943253
# 18       FullBath     int64              4      2   0.525952
# 19       HalfBath     int64              3      0   0.628374
# 20   BedroomAbvGr     int64              8      3   0.551557
# 21   KitchenAbvGr     int64              4      1   0.952941
# 22   TotRmsAbvGrd     int64             12      6   0.277509
# 23     Fireplaces     int64              4      0   0.476817
# 24    GarageYrBlt   float64             98      0   0.056055
# 25     GarageCars     int64              5      2   0.569550
# 26     GarageArea     int64            427      0   0.056055
# 27     WoodDeckSF     int64            272      0   0.523183
# 28    OpenPorchSF     int64            199      0   0.453287
# 29  EnclosedPorch     int64            120      0   0.856055
# 30      3SsnPorch     int64             20      0   0.983391
# 31    ScreenPorch     int64             76      0   0.921107
# 32       PoolArea     int64              7      0   0.995848
# 33        MiscVal     int64             20      0   0.964706
# 34         MoSold     int64             12      6   0.174394
# 35         YrSold     int64              5   2009   0.230450

# %%
# numeric_cateogicals = numeric_unique_df[numeric_unique_df["Unique Values"] <= 24]["Column"]
remove_cols = []
for row in numeric_unique_df:
    unique_values = row["Unique Values"]
    if unique_values <= 24:
        if row["Frequency"] > 0.6:
            remove_cols.append(col)
print(remove_cols)
# for col in numeric_cateogicals:
#     mode_freq = train[col].value_counts(normalize=True).sort_values(ascending=False).iloc[0]
#     if mode_freq > 0.6:
#         print("{0} mode is: \t{1}, frequnecy is: \t{2}".format(col, train[col].mode()[0], mode_freq))
#         remove_cols.append(col)
# print(remove_cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-385-882bc0ad705d> in <module>
#       2 remove_cols = []
#       3 for row in numeric_unique_df:
# ----> 4     unique_values = row["Unique Values"]
#       5     if unique_values <= 24:
#       6         if row["Frequency"] > 0.6:
#
# TypeError: string indices must be integers

# %%
train.drop(remove_cols, axis=1, inplace=True)

# %% [markdown]
# Let's get columns which have more than 24 unique values to clean outliers.

# %%
numeric_cols = numeric_unique_df[numeric_unique_df["Unique Values"] > 24]["Column"].tolist()
numeric_cols
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch']

# %%
train[numeric_cols].describe()
# Out:
#        LotFrontage        LotArea    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  1445.000000    1445.000000  1445.000000   1445.000000  1445.000000
# mean     69.706408   10436.554325  1971.035986   1984.707266   100.237370
# std      21.068267    9906.545843    30.159733     20.630222   176.279457
# min      21.000000    1300.000000  1872.000000   1950.000000     0.000000
# 25%      60.000000    7500.000000  1954.000000   1966.000000     0.000000
# 50%      69.710000    9450.000000  1972.000000   1993.000000     0.000000
# 75%      79.000000   11512.000000  2000.000000   2004.000000   161.000000
# max     313.000000  215245.000000  2010.000000   2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  \
# count  1445.000000  1445.000000  1445.000000  1445.000000  1445.000000
# mean    437.361246    47.032526   565.434602  1049.828374  1155.934256
# std     430.528008   162.084845   440.194943   415.699117   372.350986
# min       0.000000     0.000000     0.000000     0.000000   334.000000
# 25%       0.000000     0.000000   221.000000   794.000000   880.000000
# 50%     383.000000     0.000000   476.000000   990.000000  1082.000000
# 75%     706.000000     0.000000   806.000000  1291.000000  1383.000000
# max    2260.000000  1474.000000  2336.000000  3206.000000  3228.000000
#
#           2ndFlrSF    GrLivArea  GarageYrBlt   GarageArea   WoodDeckSF  \
# count  1445.000000  1445.000000  1445.000000  1445.000000  1445.000000
# mean    344.639446  1506.478893  1867.358478   465.945329    93.780623
# std     434.427784   509.765672   455.842734   202.904189   125.232497
# min       0.000000   334.000000     0.000000     0.000000     0.000000
# 25%       0.000000  1128.000000  1958.000000   326.000000     0.000000
# 50%       0.000000  1456.000000  1977.000000   478.000000     0.000000
# 75%     728.000000  1768.000000  2001.000000   576.000000   168.000000
# max    2065.000000  4676.000000  2010.000000   995.000000   857.000000
#
#        OpenPorchSF  EnclosedPorch  ScreenPorch
# count  1445.000000    1445.000000  1445.000000
# mean     46.144637      22.182007    14.929412
# std      65.830928      61.394591    55.562677
# min       0.000000       0.000000     0.000000
# 25%       0.000000       0.000000     0.000000
# 50%      24.000000       0.000000     0.000000
# 75%      68.000000       0.000000     0.000000
# max     547.000000     552.000000   480.000000

# %% [markdown]
# We can determine columns having outliers with compare 75% quantile and max value of that column

# %%
outlier_cols = ["LotFrontage", "LotArea", "MasVnrArea", 
                "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF",
                "1stFlrSF", "2ndFlrSF", "GrLivArea",
                "WoodDeckSF", 
                "OpenPorchSF", "EnclosedPorch", "ScreenPorch"
               ]

# %%
for col in outlier_cols:
    fig = plt.figure(figsize=(8,4))
    sns.scatterplot(x=train[col], y=train["SalePrice"])
    plt.show()

# %% [markdown]
# We will remove outliers of these columns

# %%
train = train[train["LotFrontage"] < 151]
train = train[train["LotArea"] < 50000]
train = train[train["MasVnrArea"] < 800]
train = train[train["BsmtFinSF1"] < 1300]
train = train[train["BsmtFinSF2"] < 1200]
train = train[train["TotalBsmtSF"] < 2500]
train = train[train["1stFlrSF"] < 2500]
train = train[train["2ndFlrSF"] < 1600]
train = train[train["GrLivArea"] < 4000]
train = train[train["WoodDeckSF"] < 600]
# train = train[train["OpenPorchSF"] < 400]
train = train[train["EnclosedPorch"] < 350]
train = train[train["ScreenPorch"] < 400]

# %%
for col in outlier_cols:
    fig = plt.figure(figsize=(8,4))
    sns.scatterplot(x=train[col], y=train["SalePrice"])
    plt.show()

# %% [markdown]
# ## Categorical columns

# %% [markdown]
# Let's invest non-numerical columns

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1346   1346  1346     1346        1346      1346      1346
# unique        5      2     3        4           4         2         5
# top          RL   Pave  Zero      Reg         Lvl    AllPub    Inside
# freq       1055   1342  1261      877        1226      1345       976
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1346         1346       1346       1346     1346       1346
# unique         3           25          9          7        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1289          220       1161       1333     1120        662
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1346     1346        1346        1346       1346      1346
# unique         6        7          14          15          5         4
# top        Gable  CompShg     VinylSd     VinylSd       None        TA
# freq        1076     1330         465         456        819       877
#
#        ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# count       1346       1346     1346     1346         1346         1346
# unique         5          6        5        5            5            7
# top           TA     CBlock       TA       TA           No          Unf
# freq        1178        604      629     1204          914          413
#
#        BsmtFinType2 Heating HeatingQC CentralAir Electrical KitchenQual  \
# count          1346    1346      1346       1346       1346        1346
# unique            7       6         5          2          5           4
# top             Unf    GasA        Ex          Y      SBrkr          TA
# freq           1155    1318       659       1253       1222         713
#
#        Functional FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# count        1346        1346       1346         1346       1346       1346
# unique          7           6          7            4          6          6
# top           Typ        Zero     Attchd          Unf         TA         TA
# freq         1256         677        785          589       1202       1214
#
#        PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# count        1346   1346  1346        1346     1346          1346
# unique          3      3     5           4        9             6
# top             Y   Zero  Zero        Zero       WD        Normal
# freq         1230   1343  1079        1299     1186          1124

# %% [markdown]
# Like numeric columns, we also get columns that have frequency of mode less than 60%

# %%
enc_cols = []
for col in categoricals.columns:
    mode_freq = train[col].value_counts(normalize=True).sort_values(ascending=False)[:1][0]
    if mode_freq < 0.75:
        enc_cols.append(col)
print(enc_cols)
# Out:
# ['LotShape', 'LotConfig', 'Neighborhood', 'HouseStyle', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageType', 'GarageFinish']

# %% [markdown]
# We will convert these non-numerical columns into numerical

# %%
le = preprocessing.LabelEncoder()
for col in enc_cols:
    train["enc_{}".format(col)] = le.fit_transform(train[col])
    test["enc_{}".format(col)] = le.fit_transform(test[col])

# %%
train = train.drop(categoricals.columns, axis=1)
test = test.drop(categoricals.columns, axis=1)

# %%
corr = abs(train.corr()["SalePrice"]).sort_values(ascending=False).drop(["SalePrice", "Id"])
corr = corr[corr > 0]

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot()
sns.barplot(corr.index, corr, color="salmon")
plt.xticks(rotation=45)
plt.setp(ax.xaxis.get_majorticklabels(), ha='right')
plt.title("Correlation between Sale Price and others")
plt.show()

# %%
features = corr.index
print("Features: ")
features = features
# Out:
# Features:

# %%
train[features].describe()
# Out:
#        OverallQual    GrLivArea   GarageCars   GarageArea  enc_ExterQual  \
# count  1346.000000  1346.000000  1346.000000  1346.000000    1346.000000
# mean      5.977712  1459.138930     1.706538   451.995542       2.600297
# std       1.290322   457.644611     0.721977   197.448012       0.619965
# min       1.000000   334.000000     0.000000     0.000000       0.000000
# 25%       5.000000  1111.250000     1.000000   308.000000       2.000000
# 50%       6.000000  1419.000000     2.000000   462.000000       3.000000
# 75%       7.000000  1721.000000     2.000000   570.000000       3.000000
# max      10.000000  3395.000000     4.000000   995.000000       3.000000
#
#        enc_BsmtQual  TotalBsmtSF     FullBath    YearBuilt  enc_GarageFinish  \
# count   1346.000000  1346.000000  1346.000000  1346.000000       1346.000000
# mean       2.374443  1005.679792     1.530461  1970.028232          1.338039
# std        0.840995   370.364198     0.535193    30.066233          0.880686
# min        0.000000     0.000000     0.000000  1872.000000          0.000000
# 25%        2.000000   783.000000     1.000000  1952.000000          1.000000
# 50%        2.000000   960.000000     2.000000  1971.000000          1.000000
# 75%        3.000000  1220.750000     2.000000  2000.000000          2.000000
# max        4.000000  2217.000000     3.000000  2009.000000          3.000000
#
#           1stFlrSF  enc_KitchenQual  YearRemodAdd  TotRmsAbvGrd  \
# count  1346.000000      1346.000000   1346.000000   1346.000000
# mean   1115.686478         2.401932   1983.933135      6.407132
# std     331.083156         0.771979     20.800557      1.547006
# min     334.000000         0.000000   1950.000000      2.000000
# 25%     864.000000         2.000000   1965.000000      5.000000
# 50%    1056.500000         3.000000   1992.000000      6.000000
# 75%    1323.000000         3.000000   2003.000000      7.000000
# max    2259.000000         3.000000   2010.000000     14.000000
#
#        enc_GarageType  enc_FireplaceQu   Fireplaces  enc_HeatingQC  \
# count     1346.000000      1346.000000  1346.000000    1346.000000
# mean         2.549777         3.897474     0.564636       1.593611
# std          1.956623         1.355658     0.621113       1.745670
# min          0.000000         0.000000     0.000000       0.000000
# 25%          1.000000         2.000000     0.000000       0.000000
# 50%          1.000000         5.000000     0.000000       1.000000
# 75%          5.000000         5.000000     1.000000       4.000000
# max          6.000000         5.000000     3.000000       4.000000
#
#        enc_Foundation   MasVnrArea  LotFrontage  OpenPorchSF     2ndFlrSF  \
# count     1346.000000  1346.000000  1346.000000  1346.000000  1346.000000
# mean         1.369985    86.015602    68.469094    44.544577   337.829123
# std          0.721289   142.597300    18.489676    63.475557   417.221736
# min          0.000000     0.000000    21.000000     0.000000     0.000000
# 25%          1.000000     0.000000    60.000000     0.000000     0.000000
# 50%          1.000000     0.000000    69.710000    22.000000     0.000000
# 75%          2.000000   140.000000    78.000000    65.000000   723.750000
# max          5.000000   788.000000   149.000000   523.000000  1540.000000
#
#             LotArea   WoodDeckSF  GarageYrBlt    BsmtUnfSF  enc_BsmtExposure  \
# count   1346.000000  1346.000000  1346.000000  1346.000000       1346.000000
# mean    9546.031204    86.664933  1861.329866   571.889302          2.373700
# std     4158.578583   115.723012   465.575464   435.892904          1.145552
# min     1300.000000     0.000000     0.000000     0.000000          0.000000
# 25%     7406.250000     0.000000  1957.000000   238.250000          2.000000
# 50%     9233.000000     0.000000  1977.000000   489.000000          3.000000
# 75%    11215.500000   160.000000  2000.000000   811.000000          3.000000
# max    45600.000000   586.000000  2010.000000  2153.000000          4.000000
#
#        enc_LotShape   BsmtFinSF1  enc_HouseStyle  BedroomAbvGr  \
# count   1346.000000  1346.000000     1346.000000   1346.000000
# mean       1.985141   387.497771        3.037890      2.861070
# std        1.400930   373.753125        1.926738      0.795442
# min        0.000000     0.000000        0.000000      0.000000
# 25%        0.000000     0.000000        2.000000      2.000000
# 50%        3.000000   350.000000        2.000000      3.000000
# 75%        3.000000   662.000000        5.000000      3.000000
# max        3.000000  1288.000000        7.000000      8.000000
#
#        enc_Neighborhood  EnclosedPorch  BsmtFullBath  enc_Exterior1st  \
# count       1346.000000    1346.000000   1346.000000      1346.000000
# mean          12.062407      21.921248      0.388559         8.843982
# std            5.981928      59.113750      0.499653         2.865931
# min            0.000000       0.000000      0.000000         0.000000
# 25%            7.000000       0.000000      0.000000         7.000000
# 50%           12.000000       0.000000      0.000000        11.000000
# 75%           17.000000       0.000000      1.000000        11.000000
# max           24.000000     330.000000      3.000000        13.000000
#
#        enc_Exterior2nd  ScreenPorch  enc_BsmtFinType1       MoSold  \
# count      1346.000000  1346.000000       1346.000000  1346.000000
# mean          9.692422    13.735513          2.864042     6.309807
# std           3.123560    51.384402          1.900522     2.693212
# min           0.000000     0.000000          0.000000     1.000000
# 25%           8.000000     0.000000          1.000000     5.000000
# 50%          12.000000     0.000000          2.000000     6.000000
# 75%          12.000000     0.000000          5.000000     8.000000
# max          14.000000   385.000000          6.000000    12.000000
#
#        OverallCond   MSSubClass       YrSold  enc_LotConfig   BsmtFinSF2  \
# count  1346.000000  1346.000000  1346.000000    1346.000000  1346.000000
# mean      5.599554    57.451709  2007.815007       3.034175    46.292719
# std       1.114674    42.597444     1.329935       1.616465   159.366307
# min       1.000000    20.000000  2006.000000       0.000000     0.000000
# 25%       5.000000    20.000000  2007.000000       2.000000     0.000000
# 50%       5.000000    50.000000  2008.000000       4.000000     0.000000
# 75%       6.000000    70.000000  2009.000000       4.000000     0.000000
# max       9.000000   190.000000  2010.000000       4.000000  1127.000000
#
#        enc_MasVnrType
# count     1346.000000
# mean         1.763001
# std          0.616621
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          4.000000

# %% [markdown]
# # Linear Regression

# %%
y = np.log(train["SalePrice"])
X = train[features]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.35, random_state=42)

# %%
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)

# %%
print("R^2 is: ", lr_model.score(X_test, y_test))
# Out:
# R^2 is:  0.8966976509430535

# %% [markdown]
# We get R-squared score approximately 89%, which is good since R-squared value is between 0 and 1, 1 meaning that all of the variance in the target is explained by the data. In general, a higher R-squared means a better fit.

# %% [markdown]
# Let's predict our model

# %%
predictions = lr_model.predict(X_test)

# %%
print("RMSE is: ", mean_squared_error(y_test, predictions))
# Out:
# RMSE is:  0.013658803200672214

# %% [markdown]
# Interpret this value is somewhat more intuitive that the R-squared value. The RMSE measures the distance betwene our predicted values and actual values.
#
# We can view this relationship graphically with a scatter plot

# %%
actual_values = y_test
fig = plt.figure(figsize=(10,7))
plt.scatter(predictions, actual_values, alpha=.7)
plt.xlabel("Predicted Price")
plt.ylabel("Acutal Price")
plt.title("Linear Regression Model")
plt.show()

# %% [markdown]
# If our predicted values were identical to the actual values, this graph would be the straight line y=x because each predicted value x would be equal to each actual value y.

# %% [markdown]
# # Make a submission

# %%
submission = pd.DataFrame()
submission['Id'] = test['Id']

# %%
lr_predictions = lr_model.predict(test[features])

# %% [markdown]
# Now we'll transform the predictions to the correct form. Remember that to reserve **log()** we do **exp()**.
#
# So we apply **np.exp()** to our predictions because we have taken the logarithm previously.

# %%
final_predictions = np.exp(lr_predictions)

# %%
print("Original predictions are: \n", predictions[:5], "\n")
print("Final predicctions are: \n", final_predictions[:5], "\n")
# Out:
# Original predictions are:
#  [11.78795847 11.80200894 12.07920018 12.24590082 12.05049805]
#
# Final predicctions are:
#  [123733.79438912 160563.30687064 182149.37884472 207062.70004485
#  185846.8279179 ]

# %% [markdown]
# Let's assign these predictions and check that everything looks good

# %%
submission["SalePrice"] = final_predictions
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  123733.794389
# 1  1462  160563.306871
# 2  1463  182149.378845
# 3  1464  207062.700045
# 4  1465  185846.827918

# %%
submission.to_csv("submission4.csv", index=False)
